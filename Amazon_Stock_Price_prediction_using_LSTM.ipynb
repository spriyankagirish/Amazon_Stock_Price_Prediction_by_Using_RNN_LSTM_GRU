# %% [markdown]
# ### Amazon Stock Price prediction using LSTM

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv(r"/content/drive/MyDrive/DS Project/Amazon Price Prediction /AMZNtrain.csv")

# %%
dataset
# Out:
#             Date         Open         High          Low        Close  \
# 0     2014-01-02   398.799988   399.359985   394.019989   397.970001
# 1     2014-01-03   398.290009   402.709991   396.220001   396.440002
# 2     2014-01-06   395.850006   397.000000   388.420013   393.630005
# 3     2014-01-07   395.040009   398.470001   394.290009   398.029999
# 4     2014-01-08   398.470001   403.000000   396.040009   401.920013
# ...          ...          ...          ...          ...          ...
# 1253  2018-12-24  1346.000000  1396.030029  1307.000000  1343.959961
# 1254  2018-12-26  1368.890015  1473.160034  1363.010010  1470.900024
# 1255  2018-12-27  1454.199951  1469.000000  1390.310059  1461.640015
# 1256  2018-12-28  1473.349976  1513.469971  1449.000000  1478.020020
# 1257  2018-12-31  1510.800049  1520.760010  1487.000000  1501.969971
#
#         Adj Close    Volume
# 0      397.970001   2137800
# 1      396.440002   2210200
# 2      393.630005   3170600
# 3      398.029999   1916000
# 4      401.920013   2316500
# ...           ...       ...
# 1253  1343.959961   7220000
# 1254  1470.900024  10411800
# 1255  1461.640015   9722000
# 1256  1478.020020   8829000
# 1257  1501.969971   6954500
#
# [1258 rows x 7 columns]

# %%
dataset.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
#convert date into pandas datetime format

dataset["Date"] = pd.to_datetime(dataset["Date"])

# %%
dataset
# Out:
#            Date         Open         High          Low        Close  \
# 0    2014-01-02   398.799988   399.359985   394.019989   397.970001
# 1    2014-01-03   398.290009   402.709991   396.220001   396.440002
# 2    2014-01-06   395.850006   397.000000   388.420013   393.630005
# 3    2014-01-07   395.040009   398.470001   394.290009   398.029999
# 4    2014-01-08   398.470001   403.000000   396.040009   401.920013
# ...         ...          ...          ...          ...          ...
# 1253 2018-12-24  1346.000000  1396.030029  1307.000000  1343.959961
# 1254 2018-12-26  1368.890015  1473.160034  1363.010010  1470.900024
# 1255 2018-12-27  1454.199951  1469.000000  1390.310059  1461.640015
# 1256 2018-12-28  1473.349976  1513.469971  1449.000000  1478.020020
# 1257 2018-12-31  1510.800049  1520.760010  1487.000000  1501.969971
#
#         Adj Close    Volume
# 0      397.970001   2137800
# 1      396.440002   2210200
# 2      393.630005   3170600
# 3      398.029999   1916000
# 4      401.920013   2316500
# ...           ...       ...
# 1253  1343.959961   7220000
# 1254  1470.900024  10411800
# 1255  1461.640015   9722000
# 1256  1478.020020   8829000
# 1257  1501.969971   6954500
#
# [1258 rows x 7 columns]

# %%
dataset.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
dataset["Date"].dt.year
# Out:
# 0       2014
# 1       2014
# 2       2014
# 3       2014
# 4       2014
#         ...
# 1253    2018
# 1254    2018
# 1255    2018
# 1256    2018
# 1257    2018
# Name: Date, Length: 1258, dtype: int32

# %%
dataset
# Out:
#            Date         Open         High          Low        Close  \
# 0    2014-01-02   398.799988   399.359985   394.019989   397.970001
# 1    2014-01-03   398.290009   402.709991   396.220001   396.440002
# 2    2014-01-06   395.850006   397.000000   388.420013   393.630005
# 3    2014-01-07   395.040009   398.470001   394.290009   398.029999
# 4    2014-01-08   398.470001   403.000000   396.040009   401.920013
# ...         ...          ...          ...          ...          ...
# 1253 2018-12-24  1346.000000  1396.030029  1307.000000  1343.959961
# 1254 2018-12-26  1368.890015  1473.160034  1363.010010  1470.900024
# 1255 2018-12-27  1454.199951  1469.000000  1390.310059  1461.640015
# 1256 2018-12-28  1473.349976  1513.469971  1449.000000  1478.020020
# 1257 2018-12-31  1510.800049  1520.760010  1487.000000  1501.969971
#
#         Adj Close    Volume
# 0      397.970001   2137800
# 1      396.440002   2210200
# 2      393.630005   3170600
# 3      398.029999   1916000
# 4      401.920013   2316500
# ...           ...       ...
# 1253  1343.959961   7220000
# 1254  1470.900024  10411800
# 1255  1461.640015   9722000
# 1256  1478.020020   8829000
# 1257  1501.969971   6954500
#
# [1258 rows x 7 columns]

# %%
#Based on the previous days stock prices predict the next day stock price

# %%
dataset = dataset[["Date","Open"]]

# %%
dataset
# Out:
#            Date         Open
# 0    2014-01-02   398.799988
# 1    2014-01-03   398.290009
# 2    2014-01-06   395.850006
# 3    2014-01-07   395.040009
# 4    2014-01-08   398.470001
# ...         ...          ...
# 1253 2018-12-24  1346.000000
# 1254 2018-12-26  1368.890015
# 1255 2018-12-27  1454.199951
# 1256 2018-12-28  1473.349976
# 1257 2018-12-31  1510.800049
#
# [1258 rows x 2 columns]

# %%
dataset = dataset.sample(frac = 1)

# %%
dataset
# Out:
#            Date         Open
# 738  2016-12-06   763.989990
# 139  2014-07-23   359.049988
# 876  2017-06-26  1008.500000
# 239  2014-12-12   303.989990
# 48   2014-03-13   376.619995
# ...         ...          ...
# 370  2015-06-23   435.589996
# 796  2017-03-02   853.080017
# 267  2015-01-26   311.820007
# 1191 2018-09-25  1942.900024
# 61   2014-04-01   338.089996
#
# [1258 rows x 2 columns]

# %%
dataset.set_index("Date", inplace = True)

# %%
dataset
# Out:
#                    Open
# Date
# 2016-12-06   763.989990
# 2014-07-23   359.049988
# 2017-06-26  1008.500000
# 2014-12-12   303.989990
# 2014-03-13   376.619995
# ...                 ...
# 2015-06-23   435.589996
# 2017-03-02   853.080017
# 2015-01-26   311.820007
# 2018-09-25  1942.900024
# 2014-04-01   338.089996
#
# [1258 rows x 1 columns]

# %%
#sort_index -- to sort by date -- to maintain the sequntial data
dataset.sort_index(inplace = True)

# %%
dataset
# Out:
#                    Open
# Date
# 2014-01-02   398.799988
# 2014-01-03   398.290009
# 2014-01-06   395.850006
# 2014-01-07   395.040009
# 2014-01-08   398.470001
# ...                 ...
# 2018-12-24  1346.000000
# 2018-12-26  1368.890015
# 2018-12-27  1454.199951
# 2018-12-28  1473.349976
# 2018-12-31  1510.800049
#
# [1258 rows x 1 columns]

# %%
dataset.isnull().any()
# Out:
# Open    False
# dtype: bool

# %% [markdown]
# ###### Check for gaps

# %%
dataset
# Out:
#                    Open
# Date
# 2014-01-02   398.799988
# 2014-01-03   398.290009
# 2014-01-06   395.850006
# 2014-01-07   395.040009
# 2014-01-08   398.470001
# ...                 ...
# 2018-12-24  1346.000000
# 2018-12-26  1368.890015
# 2018-12-27  1454.199951
# 2018-12-28  1473.349976
# 2018-12-31  1510.800049
#
# [1258 rows x 1 columns]

# %%
diff = dataset.index[3] - dataset.index[2]

# %%
diff.days
# Out:
# 1

# %%
for idx in range(1, len(dataset)):
    diff = dataset.index[idx] - dataset.index[idx-1]
    if diff.days > 4:
        print("Gap is high")
        print(dataset.index[idx], diff.days)

# %%
dataset
# Out:
#                    Open
# Date
# 2014-01-02   398.799988
# 2014-01-03   398.290009
# 2014-01-06   395.850006
# 2014-01-07   395.040009
# 2014-01-08   398.470001
# ...                 ...
# 2018-12-24  1346.000000
# 2018-12-26  1368.890015
# 2018-12-27  1454.199951
# 2018-12-28  1473.349976
# 2018-12-31  1510.800049
#
# [1258 rows x 1 columns]

# %%
plt.figure(figsize = (15,5))
plt.plot(dataset)

plt.xlabel("Date")
plt.ylabel("Open Price")
plt.show()

# %% [markdown]
# ### Train and test split

# %%
len(dataset)
# Out:
# 1258

# %%
round(len(dataset) * 0.8)
# Out:
# 1006

# %%
len(dataset) -round(len(dataset) * 0.8)
# Out:
# 252

# %%
train_dataset = dataset.iloc[0:round(len(dataset) * 0.8)]

# %%
train_dataset
# Out:
#                    Open
# Date
# 2014-01-02   398.799988
# 2014-01-03   398.290009
# 2014-01-06   395.850006
# 2014-01-07   395.040009
# 2014-01-08   398.470001
# ...                 ...
# 2017-12-21  1175.900024
# 2017-12-22  1172.079956
# 2017-12-26  1168.359985
# 2017-12-27  1179.910034
# 2017-12-28  1189.000000
#
# [1006 rows x 1 columns]

# %%
test_dataset = dataset.iloc[round(len(dataset) * 0.8): ]

# %%
test_dataset
# Out:
#                    Open
# Date
# 2017-12-29  1182.349976
# 2018-01-02  1172.000000
# 2018-01-03  1188.300049
# 2018-01-04  1205.000000
# 2018-01-05  1217.510010
# ...                 ...
# 2018-12-24  1346.000000
# 2018-12-26  1368.890015
# 2018-12-27  1454.199951
# 2018-12-28  1473.349976
# 2018-12-31  1510.800049
#
# [252 rows x 1 columns]

# %% [markdown]
# ### Min Max Scaler

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
sc = MinMaxScaler()

# %%
train_dataset = sc.fit_transform(train_dataset)

# %%
test_dataset = sc.transform(test_dataset)

# %% [markdown]
# ### Prepare the data for RNN model

# %%
train_dataset
# Out:
# array([[0.12428297],
#        [0.12372894],
#        [0.12107814],
#        ...,
#        [0.96032503],
#        [0.97287288],
#        [0.98274813]])

# %%
X_train = []
y_train = []

# %%
num_of_days = 60

# %%
for i in range(num_of_days, len(train_dataset)):

    X_train.append(train_dataset[i-num_of_days:i,:])
    y_train.append(train_dataset[i,:])

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)

# %%
X_train.shape
# Out:
# (946, 60, 1)

# %%
y_train.shape
# Out:
# (946, 1)

# %% [markdown]
# ### Build the RNN Architecture

# %%
from tensorflow.keras import Sequential

# %%
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout

# %% [markdown]
# ### Init the Model

# %%
lstm_model = Sequential()

# %% [markdown]
# #### Add the input layer

# %%
inp_layer = Input(shape = (60, 1))

# %%
lstm_model.add(inp_layer)

# %% [markdown]
# #### Add the LSTM Layer

# %%
#kernel_initializer -- init strategy for weights
#recurrent_initializer -- init strategy for recurrent weights
#return_sequences -- to return sequential output --
#True -- return sequence, False -- Return vector
#units -- no of neurons in layer
lstm_layer_1 = LSTM(kernel_initializer = "glorot_uniform",
                  recurrent_initializer = "glorot_uniform",
                  return_sequences = True,
                  units = 100)

# %%
lstm_model.add(lstm_layer_1)

# %%
#% of neurons to deactivate randomly
lstm_model.add(Dropout(0.1))

# %%
lstm_layer_2 = LSTM(kernel_initializer = "glorot_uniform",
                        recurrent_initializer = "glorot_uniform",
                        return_sequences = False,
                        units = 150)

# %%
lstm_model.add(lstm_layer_2)

# %%
lstm_model.add(Dropout(0.1))

# %% [markdown]
# ### Add output layer

# %%
output_layer = Dense(kernel_initializer = "glorot_uniform",
                    activation = "linear",
                     units = 1 ) #regression problem

# %%
lstm_model.add(output_layer)

# %%
lstm_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 60, 100)             │          40,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 60, 100)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 150)                 │         150,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 150)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │             151 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 191,551 (748.25 KB)
#  Trainable params: 191,551 (748.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.utils import plot_model

# %%
plot_model(lstm_model,
           show_shapes =  True,
       show_layer_names = True,
          show_dtype = True,show_layer_activations = True, expand_nested  = True )

# %%
import tensorflow as tf
from tensorflow.keras.metrics import Metric

# %%
class RMSEMetric(Metric): #inherit class Metric
    def __init__(self, name="rmse", **kwargs):
        super(RMSEMetric, self).__init__(name=name, **kwargs)
        self.sum_squared_errors = self.add_weight(name="sse", initializer="zeros")
        self.count = self.add_weight(name="count", initializer="zeros")

    def update_state(self, y_true, y_pred, sample_weight=None):
        error = tf.math.squared_difference(y_true, y_pred)
        if sample_weight is not None:
            error = tf.multiply(error, sample_weight)
        self.sum_squared_errors.assign_add(tf.reduce_sum(error))
        self.count.assign_add(tf.cast(tf.size(y_true), dtype=self.count.dtype))

    def result(self):
        return tf.sqrt(self.sum_squared_errors / self.count)

    def reset_state(self):
        self.sum_squared_errors.assign(0.0)
        self.count.assign(0.0)

# %%
lstm_model.compile(loss = "mse", optimizer = "adam", metrics = [RMSEMetric()])

# %% [markdown]
# ### Train the model

# %%
lstm_model.fit(X_train, y_train, epochs = 15, batch_size = 32)
# Out:
# Epoch 1/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 9s 191ms/step - loss: 0.0486 - rmse: 0.2057
# Epoch 2/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - loss: 0.0023 - rmse: 0.0479
# Epoch 3/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - loss: 0.0012 - rmse: 0.0350
# Epoch 4/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 6s 190ms/step - loss: 0.0010 - rmse: 0.0318
# Epoch 5/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step - loss: 0.0011 - rmse: 0.0332
# Epoch 6/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 6s 201ms/step - loss: 0.0011 - rmse: 0.0334
# Epoch 7/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - loss: 0.0010 - rmse: 0.0323
# Epoch 8/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 6s 164ms/step - loss: 0.0011 - rmse: 0.0333
# Epoch 9/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 6s 211ms/step - loss: 9.8068e-04 - rmse: 0.0313
# Epoch 10/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 8s 137ms/step - loss: 8.7138e-04 - rmse: 0.0295
# Epoch 11/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 6s 214ms/step - loss: 9.1566e-04 - rmse: 0.0302
# Epoch 12/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 8s 139ms/step - loss: 9.1555e-04 - rmse: 0.0302
# Epoch 13/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 210ms/step - loss: 0.0010 - rmse: 0.0321
# Epoch 14/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 8s 137ms/step - loss: 9.1258e-04 - rmse: 0.0302
# Epoch 15/15
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 7s 194ms/step - loss: 0.0010 - rmse: 0.0318

# %% [markdown]
# ## Predictions

# %%
len(test_dataset)
# Out:
# 252

# %%
test_data = np.concatenate((train_dataset[-60:], test_dataset), axis = 0)

# %%
test_data
# Out:
# array([[0.72767471],
#        [0.74482878],
#        [0.75095604],
#        [0.77007647],
#        [0.77380278],
#        [0.76793631],
#        [0.77395489],
#        [0.7850252 ],
#        [0.7865896 ],
#        [0.78349342],
#        [0.78749133],
#        [0.76655658],
#        [0.77039156],
#        [0.76300406],
#        [0.74374239],
#        [0.7535199 ],
#        [0.75605121],
#        [0.84058319],
#        [0.88063837],
#        [0.89583695],
#        [0.89192597],
#        [0.88368031],
#        [0.87644492],
#        [0.89599993],
#        [0.91293671],
#        [0.9108508 ],
#        [0.91426208],
#        [0.91441419],
#        [0.91104641],
#        [0.91877062],
#        [0.91540284],
#        [0.91882499],
#        [0.92764647],
#        [0.91840129],
#        [0.92175819],
#        [0.93060142],
#        [0.95200324],
#        [0.99758825],
#        [1.        ],
#        [0.98904924],
#        [0.95895617],
#        [0.96433387],
#        [0.9662893 ],
#        [0.91676083],
#        [0.92733138],
#        [0.9475382 ],
#        [0.9625413 ],
#        [0.95624019],
#        [0.95831523],
#        [0.96210672],
#        [0.95527329],
#        [0.97191685],
#        [0.98097731],
#        [0.98291111],
#        [0.98437771],
#        [0.96851645],
#        [0.96436636],
#        [0.96032503],
#        [0.97287288],
#        [0.98274813],
#        [0.97552361],
#        [0.9642795 ],
#        [0.98198771],
#        [1.00013036],
#        [1.01372111],
#        [1.03380844],
#        [1.05651401],
#        [1.04374893],
#        [1.05959932],
#        [1.07442857],
#        [1.12832435],
#        [1.11663478],
#        [1.09676467],
#        [1.11637406],
#        [1.10026295],
#        [1.14471793],
#        [1.184621  ],
#        [1.17721188],
#        [1.20329611],
#        [1.22194947],
#        [1.21542026],
#        [1.2677082 ],
#        [1.26086389],
#        [1.29605207],
#        [1.21482269],
#        [1.17010685],
#        [1.26520945],
#        [1.24422046],
#        [1.18317615],
#        [1.17359425],
#        [1.19669091],
#        [1.21876629],
#        [1.28464498],
#        [1.27430252],
#        [1.2624826 ],
#        [1.30431948],
#        [1.31557446],
#        [1.31555271],
#        [1.33061005],
#        [1.34723187],
#        [1.3418108 ],
#        [1.3353902 ],
#        [1.28704585],
#        [1.31435771],
#        [1.35668341],
#        [1.3494264 ],
#        [1.37493481],
#        [1.38960107],
#        [1.42121498],
#        [1.44659303],
#        [1.42599512],
#        [1.42382234],
#        [1.41127449],
#        [1.37985618],
#        [1.37530414],
#        [1.41453366],
#        [1.39174122],
#        [1.36299539],
#        [1.35320701],
#        [1.39926996],
#        [1.26303667],
#        [1.21849469],
#        [1.23111853],
#        [1.20261168],
#        [1.16660871],
#        [1.25759384],
#        [1.24453542],
#        [1.23916872],
#        [1.24672995],
#        [1.2548235 ],
#        [1.25488875],
#        [1.26536156],
#        [1.26086389],
#        [1.27965848],
#        [1.33653096],
#        [1.36756905],
#        [1.38710232],
#        [1.37133879],
#        [1.35950813],
#        [1.27498695],
#        [1.30433035],
#        [1.46620242],
#        [1.41024247],
#        [1.38929685],
#        [1.40859114],
#        [1.38580958],
#        [1.38846031],
#        [1.41767334],
#        [1.42382234],
#        [1.42925429],
#        [1.43846685],
#        [1.4411937 ],
#        [1.43359985],
#        [1.41600039],
#        [1.40481052],
#        [1.40813494],
#        [1.40897135],
#        [1.41295845],
#        [1.41827091],
#        [1.39780336],
#        [1.42711414],
#        [1.43251346],
#        [1.43002559],
#        [1.44891792],
#        [1.45424125],
#        [1.46948333],
#        [1.48237877],
#        [1.50854986],
#        [1.54279289],
#        [1.53632892],
#        [1.51738222],
#        [1.51780593],
#        [1.53028853],
#        [1.54094608],
#        [1.55253777],
#        [1.55310272],
#        [1.54469407],
#        [1.54771427],
#        [1.58406482],
#        [1.60307664],
#        [1.58419518],
#        [1.54062011],
#        [1.50787631],
#        [1.54670387],
#        [1.50806104],
#        [1.55636189],
#        [1.51909867],
#        [1.56392312],
#        [1.54373804],
#        [1.5335477 ],
#        [1.56402099],
#        [1.57975189],
#        [1.57916519],
#        [1.60797627],
#        [1.6508018 ],
#        [1.67037843],
#        [1.65909096],
#        [1.69867894],
#        [1.67853723],
#        [1.67370285],
#        [1.65979701],
#        [1.67804841],
#        [1.6783635 ],
#        [1.68890143],
#        [1.72915222],
#        [1.67622321],
#        [1.6318551 ],
#        [1.62915   ],
#        [1.6343321 ],
#        [1.68753257],
#        [1.67457201],
#        [1.70577309],
#        [1.712802  ],
#        [1.73561619],
#        [1.74268859],
#        [1.75354162],
#        [1.77623631],
#        [1.76554628],
#        [1.75945151],
#        [1.73974452],
#        [1.74492649],
#        [1.73344341],
#        [1.72979315],
#        [1.76296066],
#        [1.76658917],
#        [1.77146705],
#        [1.79616066],
#        [1.81323868],
#        [1.86100733],
#        [1.8714149 ],
#        [1.8925995 ],
#        [1.90521247],
#        [1.87088258],
#        [1.7972253 ],
#        [1.83230487],
#        [1.78588346],
#        [1.85729183],
#        [1.86381017],
#        [1.85612945],
#        [1.81462929],
#        [1.77543239],
#        [1.79916998],
#        [1.79708407],
#        [1.81407522],
#        [1.75928866],
#        [1.80177734],
#        [1.82958889],
#        [1.85646617],
#        [1.86860119],
#        [1.88769987],
#        [1.8637993 ],
#        [1.84392919],
#        [1.8084043 ],
#        [1.77471534],
#        [1.72692507],
#        [1.71170474],
#        [1.70942335],
#        [1.56396661],
#        [1.65522335],
#        [1.64110028],
#        [1.6286068 ],
#        [1.69301889],
#        [1.66987873],
#        [1.63041024],
#        [1.62915   ],
#        [1.58378235],
#        [1.61796013],
#        [1.54152177],
#        [1.48312832],
#        [1.49443767],
#        [1.30557973],
#        [1.39665173],
#        [1.45481707],
#        [1.51463362],
#        [1.49179769],
#        [1.44918952],
#        [1.50856074],
#        [1.59764469],
#        [1.57320093],
#        [1.5359812 ],
#        [1.48280248],
#        [1.4904397 ],
#        [1.40862376],
#        [1.41567442],
#        [1.4042782 ],
#        [1.25271597],
#        [1.3673192 ],
#        [1.33908395],
#        [1.36298452],
#        [1.40317006],
#        [1.44437688],
#        [1.51072264],
#        [1.51562227],
#        [1.61335385],
#        [1.59873108],
#        [1.4454089 ],
#        [1.5434012 ],
#        [1.45515378],
#        [1.51399269],
#        [1.50421518],
#        [1.51616547],
#        [1.4705371 ],
#        [1.39231704],
#        [1.36407091],
#        [1.36738445],
#        [1.30323309],
#        [1.28258081],
#        [1.15331131],
#        [1.17817879],
#        [1.27085862],
#        [1.29166301],
#        [1.33234838]])

# %%
X_test = []
y_test = []

# %%
for i in range(num_of_days, len(test_data)):

    X_test.append(test_data[i-num_of_days:i,:])
    y_test.append(test_data[i,:])

# %%
X_test = np.array(X_test)
y_test = np.array(y_test)

# %%
X_test.shape
# Out:
# (252, 60, 1)

# %%
y_pred = lstm_model.predict(X_test)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step

# %%
y_pred
# Out:
# array([[0.9707998 ],
#        [0.9718119 ],
#        [0.97192466],
#        [0.97264695],
#        [0.9748865 ],
#        [0.9788502 ],
#        [0.9850139 ],
#        [0.99370736],
#        [1.002603  ],
#        [1.0121512 ],
#        [1.0224447 ],
#        [1.0361068 ],
#        [1.0501579 ],
#        [1.0622431 ],
#        [1.0735788 ],
#        [1.0825052 ],
#        [1.0922427 ],
#        [1.1043676 ],
#        [1.1166351 ],
#        [1.1299374 ],
#        [1.1441822 ],
#        [1.1575919 ],
#        [1.1730447 ],
#        [1.1881635 ],
#        [1.2044017 ],
#        [1.2147434 ],
#        [1.217793  ],
#        [1.2222921 ],
#        [1.2256563 ],
#        [1.2240456 ],
#        [1.2188303 ],
#        [1.2131288 ],
#        [1.2088461 ],
#        [1.2100843 ],
#        [1.2139667 ],
#        [1.2186204 ],
#        [1.2263184 ],
#        [1.2361187 ],
#        [1.2466253 ],
#        [1.2579042 ],
#        [1.2699851 ],
#        [1.2813609 ],
#        [1.2910993 ],
#        [1.295911  ],
#        [1.2991464 ],
#        [1.3038007 ],
#        [1.3084106 ],
#        [1.3143977 ],
#        [1.3217496 ],
#        [1.331536  ],
#        [1.343813  ],
#        [1.3554373 ],
#        [1.3657906 ],
#        [1.3737812 ],
#        [1.3776474 ],
#        [1.378362  ],
#        [1.3795499 ],
#        [1.3792733 ],
#        [1.3762437 ],
#        [1.3710718 ],
#        [1.3679156 ],
#        [1.3570526 ],
#        [1.339479  ],
#        [1.319655  ],
#        [1.2976713 ],
#        [1.2734208 ],
#        [1.2554802 ],
#        [1.2416421 ],
#        [1.2311782 ],
#        [1.2242088 ],
#        [1.2205667 ],
#        [1.2193846 ],
#        [1.2206455 ],
#        [1.2231299 ],
#        [1.227552  ],
#        [1.2366859 ],
#        [1.2501813 ],
#        [1.2668458 ],
#        [1.2833697 ],
#        [1.2979621 ],
#        [1.3047199 ],
#        [1.308131  ],
#        [1.3196701 ],
#        [1.3314035 ],
#        [1.3413163 ],
#        [1.3507049 ],
#        [1.3575101 ],
#        [1.3624115 ],
#        [1.3676286 ],
#        [1.3729644 ],
#        [1.378339  ],
#        [1.3839512 ],
#        [1.3894722 ],
#        [1.3940415 ],
#        [1.3965427 ],
#        [1.3968463 ],
#        [1.3959444 ],
#        [1.3943396 ],
#        [1.3926328 ],
#        [1.3913021 ],
#        [1.3889309 ],
#        [1.3880641 ],
#        [1.3884705 ],
#        [1.3895079 ],
#        [1.3921561 ],
#        [1.3959603 ],
#        [1.4012595 ],
#        [1.4079733 ],
#        [1.4168354 ],
#        [1.4286472 ],
#        [1.4410228 ],
#        [1.4517171 ],
#        [1.460694  ],
#        [1.4687449 ],
#        [1.476274  ],
#        [1.4836498 ],
#        [1.4903967 ],
#        [1.4957105 ],
#        [1.499953  ],
#        [1.5055581 ],
#        [1.5127329 ],
#        [1.5191195 ],
#        [1.5217953 ],
#        [1.5199229 ],
#        [1.5178915 ],
#        [1.5131541 ],
#        [1.5103141 ],
#        [1.5062163 ],
#        [1.5046941 ],
#        [1.5034174 ],
#        [1.5018289 ],
#        [1.5021931 ],
#        [1.5046984 ],
#        [1.5083337 ],
#        [1.514358  ],
#        [1.5241979 ],
#        [1.5369399 ],
#        [1.5498894 ],
#        [1.5647186 ],
#        [1.5782574 ],
#        [1.5898124 ],
#        [1.5983988 ],
#        [1.6057073 ],
#        [1.611597  ],
#        [1.6168283 ],
#        [1.6238078 ],
#        [1.6278063 ],
#        [1.6269845 ],
#        [1.6231201 ],
#        [1.6178672 ],
#        [1.6154734 ],
#        [1.6139753 ],
#        [1.6152558 ],
#        [1.6185522 ],
#        [1.6243855 ],
#        [1.6318187 ],
#        [1.640459  ],
#        [1.6507045 ],
#        [1.6604913 ],
#        [1.6689783 ],
#        [1.6748029 ],
#        [1.6789354 ],
#        [1.6809119 ],
#        [1.6811724 ],
#        [1.6824436 ],
#        [1.6843274 ],
#        [1.686771  ],
#        [1.690966  ],
#        [1.6969701 ],
#        [1.7067012 ],
#        [1.7185861 ],
#        [1.7323445 ],
#        [1.7470524 ],
#        [1.7591088 ],
#        [1.7641202 ],
#        [1.7668744 ],
#        [1.7648041 ],
#        [1.7645634 ],
#        [1.7655075 ],
#        [1.7666239 ],
#        [1.7651671 ],
#        [1.7598716 ],
#        [1.7541841 ],
#        [1.7483485 ],
#        [1.743911  ],
#        [1.7370752 ],
#        [1.7321876 ],
#        [1.7304289 ],
#        [1.7323915 ],
#        [1.7372681 ],
#        [1.7448616 ],
#        [1.7520778 ],
#        [1.7574356 ],
#        [1.759075  ],
#        [1.7562459 ],
#        [1.747838  ],
#        [1.7356657 ],
#        [1.7217901 ],
#        [1.6983286 ],
#        [1.6769338 ],
#        [1.6568277 ],
#        [1.6381804 ],
#        [1.6259835 ],
#        [1.6169761 ],
#        [1.6082556 ],
#        [1.6004639 ],
#        [1.5908756 ],
#        [1.5832481 ],
#        [1.572257  ],
#        [1.5563986 ],
#        [1.5394586 ],
#        [1.5104223 ],
#        [1.4823718 ],
#        [1.4601315 ],
#        [1.4468397 ],
#        [1.4385564 ],
#        [1.4314729 ],
#        [1.4298017 ],
#        [1.4373988 ],
#        [1.4485977 ],
#        [1.4591091 ],
#        [1.4651506 ],
#        [1.468605  ],
#        [1.4646981 ],
#        [1.4570663 ],
#        [1.4466827 ],
#        [1.4251738 ],
#        [1.406081  ],
#        [1.3873624 ],
#        [1.3718458 ],
#        [1.3620147 ],
#        [1.3591465 ],
#        [1.3652874 ],
#        [1.3770249 ],
#        [1.3980858 ],
#        [1.4224882 ],
#        [1.4374341 ],
#        [1.4522759 ],
#        [1.4597833 ],
#        [1.4662365 ],
#        [1.4706151 ],
#        [1.4741477 ],
#        [1.4738088 ],
#        [1.4659964 ],
#        [1.4522854 ],
#        [1.4359313 ],
#        [1.414626  ],
#        [1.3903847 ],
#        [1.3572665 ],
#        [1.3227148 ],
#        [1.2954845 ],
#        [1.275845  ]], dtype=float32)

# %%
y_test
# Out:
# array([[0.97552361],
#        [0.9642795 ],
#        [0.98198771],
#        [1.00013036],
#        [1.01372111],
#        [1.03380844],
#        [1.05651401],
#        [1.04374893],
#        [1.05959932],
#        [1.07442857],
#        [1.12832435],
#        [1.11663478],
#        [1.09676467],
#        [1.11637406],
#        [1.10026295],
#        [1.14471793],
#        [1.184621  ],
#        [1.17721188],
#        [1.20329611],
#        [1.22194947],
#        [1.21542026],
#        [1.2677082 ],
#        [1.26086389],
#        [1.29605207],
#        [1.21482269],
#        [1.17010685],
#        [1.26520945],
#        [1.24422046],
#        [1.18317615],
#        [1.17359425],
#        [1.19669091],
#        [1.21876629],
#        [1.28464498],
#        [1.27430252],
#        [1.2624826 ],
#        [1.30431948],
#        [1.31557446],
#        [1.31555271],
#        [1.33061005],
#        [1.34723187],
#        [1.3418108 ],
#        [1.3353902 ],
#        [1.28704585],
#        [1.31435771],
#        [1.35668341],
#        [1.3494264 ],
#        [1.37493481],
#        [1.38960107],
#        [1.42121498],
#        [1.44659303],
#        [1.42599512],
#        [1.42382234],
#        [1.41127449],
#        [1.37985618],
#        [1.37530414],
#        [1.41453366],
#        [1.39174122],
#        [1.36299539],
#        [1.35320701],
#        [1.39926996],
#        [1.26303667],
#        [1.21849469],
#        [1.23111853],
#        [1.20261168],
#        [1.16660871],
#        [1.25759384],
#        [1.24453542],
#        [1.23916872],
#        [1.24672995],
#        [1.2548235 ],
#        [1.25488875],
#        [1.26536156],
#        [1.26086389],
#        [1.27965848],
#        [1.33653096],
#        [1.36756905],
#        [1.38710232],
#        [1.37133879],
#        [1.35950813],
#        [1.27498695],
#        [1.30433035],
#        [1.46620242],
#        [1.41024247],
#        [1.38929685],
#        [1.40859114],
#        [1.38580958],
#        [1.38846031],
#        [1.41767334],
#        [1.42382234],
#        [1.42925429],
#        [1.43846685],
#        [1.4411937 ],
#        [1.43359985],
#        [1.41600039],
#        [1.40481052],
#        [1.40813494],
#        [1.40897135],
#        [1.41295845],
#        [1.41827091],
#        [1.39780336],
#        [1.42711414],
#        [1.43251346],
#        [1.43002559],
#        [1.44891792],
#        [1.45424125],
#        [1.46948333],
#        [1.48237877],
#        [1.50854986],
#        [1.54279289],
#        [1.53632892],
#        [1.51738222],
#        [1.51780593],
#        [1.53028853],
#        [1.54094608],
#        [1.55253777],
#        [1.55310272],
#        [1.54469407],
#        [1.54771427],
#        [1.58406482],
#        [1.60307664],
#        [1.58419518],
#        [1.54062011],
#        [1.50787631],
#        [1.54670387],
#        [1.50806104],
#        [1.55636189],
#        [1.51909867],
#        [1.56392312],
#        [1.54373804],
#        [1.5335477 ],
#        [1.56402099],
#        [1.57975189],
#        [1.57916519],
#        [1.60797627],
#        [1.6508018 ],
#        [1.67037843],
#        [1.65909096],
#        [1.69867894],
#        [1.67853723],
#        [1.67370285],
#        [1.65979701],
#        [1.67804841],
#        [1.6783635 ],
#        [1.68890143],
#        [1.72915222],
#        [1.67622321],
#        [1.6318551 ],
#        [1.62915   ],
#        [1.6343321 ],
#        [1.68753257],
#        [1.67457201],
#        [1.70577309],
#        [1.712802  ],
#        [1.73561619],
#        [1.74268859],
#        [1.75354162],
#        [1.77623631],
#        [1.76554628],
#        [1.75945151],
#        [1.73974452],
#        [1.74492649],
#        [1.73344341],
#        [1.72979315],
#        [1.76296066],
#        [1.76658917],
#        [1.77146705],
#        [1.79616066],
#        [1.81323868],
#        [1.86100733],
#        [1.8714149 ],
#        [1.8925995 ],
#        [1.90521247],
#        [1.87088258],
#        [1.7972253 ],
#        [1.83230487],
#        [1.78588346],
#        [1.85729183],
#        [1.86381017],
#        [1.85612945],
#        [1.81462929],
#        [1.77543239],
#        [1.79916998],
#        [1.79708407],
#        [1.81407522],
#        [1.75928866],
#        [1.80177734],
#        [1.82958889],
#        [1.85646617],
#        [1.86860119],
#        [1.88769987],
#        [1.8637993 ],
#        [1.84392919],
#        [1.8084043 ],
#        [1.77471534],
#        [1.72692507],
#        [1.71170474],
#        [1.70942335],
#        [1.56396661],
#        [1.65522335],
#        [1.64110028],
#        [1.6286068 ],
#        [1.69301889],
#        [1.66987873],
#        [1.63041024],
#        [1.62915   ],
#        [1.58378235],
#        [1.61796013],
#        [1.54152177],
#        [1.48312832],
#        [1.49443767],
#        [1.30557973],
#        [1.39665173],
#        [1.45481707],
#        [1.51463362],
#        [1.49179769],
#        [1.44918952],
#        [1.50856074],
#        [1.59764469],
#        [1.57320093],
#        [1.5359812 ],
#        [1.48280248],
#        [1.4904397 ],
#        [1.40862376],
#        [1.41567442],
#        [1.4042782 ],
#        [1.25271597],
#        [1.3673192 ],
#        [1.33908395],
#        [1.36298452],
#        [1.40317006],
#        [1.44437688],
#        [1.51072264],
#        [1.51562227],
#        [1.61335385],
#        [1.59873108],
#        [1.4454089 ],
#        [1.5434012 ],
#        [1.45515378],
#        [1.51399269],
#        [1.50421518],
#        [1.51616547],
#        [1.4705371 ],
#        [1.39231704],
#        [1.36407091],
#        [1.36738445],
#        [1.30323309],
#        [1.28258081],
#        [1.15331131],
#        [1.17817879],
#        [1.27085862],
#        [1.29166301],
#        [1.33234838]])

# %%
y_pred = sc.inverse_transform(y_pred)

# %%
y_test = sc.inverse_transform(y_test)

# %%
y_pred
# Out:
# array([[1178.0018],
#        [1178.9335],
#        [1179.0372],
#        [1179.7021],
#        [1181.7634],
#        [1185.412 ],
#        [1191.0856],
#        [1199.0878],
#        [1207.2761],
#        [1216.0651],
#        [1225.5399],
#        [1238.1156],
#        [1251.0494],
#        [1262.1736],
#        [1272.6079],
#        [1280.8245],
#        [1289.7876],
#        [1300.9484],
#        [1312.2404],
#        [1324.4849],
#        [1337.5969],
#        [1349.9403],
#        [1364.1642],
#        [1378.0808],
#        [1393.0277],
#        [1402.547 ],
#        [1405.3541],
#        [1409.4955],
#        [1412.5922],
#        [1411.1096],
#        [1406.309 ],
#        [1401.0608],
#        [1397.1187],
#        [1398.2584],
#        [1401.8322],
#        [1406.1157],
#        [1413.2015],
#        [1422.2225],
#        [1431.8937],
#        [1442.2756],
#        [1453.3959],
#        [1463.8671],
#        [1472.8312],
#        [1477.2601],
#        [1480.2383],
#        [1484.5225],
#        [1488.7659],
#        [1494.2769],
#        [1501.0441],
#        [1510.0524],
#        [1521.353 ],
#        [1532.053 ],
#        [1541.583 ],
#        [1548.9381],
#        [1552.497 ],
#        [1553.1548],
#        [1554.248 ],
#        [1553.9935],
#        [1551.2048],
#        [1546.4442],
#        [1543.5391],
#        [1533.5398],
#        [1517.3636],
#        [1499.116 ],
#        [1478.8805],
#        [1456.5585],
#        [1440.0444],
#        [1427.3068],
#        [1417.6749],
#        [1411.2598],
#        [1407.9073],
#        [1406.8191],
#        [1407.9799],
#        [1410.2666],
#        [1414.3372],
#        [1422.7446],
#        [1435.167 ],
#        [1450.5062],
#        [1465.7162],
#        [1479.1482],
#        [1485.3687],
#        [1488.5084],
#        [1499.13  ],
#        [1509.9303],
#        [1519.0549],
#        [1527.6969],
#        [1533.9609],
#        [1538.4725],
#        [1543.2748],
#        [1548.1863],
#        [1553.1335],
#        [1558.2994],
#        [1563.3815],
#        [1567.5874],
#        [1569.8896],
#        [1570.1691],
#        [1569.3389],
#        [1567.8617],
#        [1566.2908],
#        [1565.0658],
#        [1562.8832],
#        [1562.0853],
#        [1562.4594],
#        [1563.4143],
#        [1565.8519],
#        [1569.3536],
#        [1574.2314],
#        [1580.4113],
#        [1588.5687],
#        [1599.4412],
#        [1610.8326],
#        [1620.6766],
#        [1628.9396],
#        [1636.3503],
#        [1643.2808],
#        [1650.0701],
#        [1656.2804],
#        [1661.1716],
#        [1665.0768],
#        [1670.2362],
#        [1676.8403],
#        [1682.7191],
#        [1685.1821],
#        [1683.4586],
#        [1681.5889],
#        [1677.2281],
#        [1674.614 ],
#        [1670.842 ],
#        [1669.4409],
#        [1668.2656],
#        [1666.8035],
#        [1667.1388],
#        [1669.4448],
#        [1672.791 ],
#        [1678.3363],
#        [1687.3938],
#        [1699.1224],
#        [1711.0422],
#        [1724.6923],
#        [1737.1544],
#        [1747.7905],
#        [1755.6942],
#        [1762.4215],
#        [1767.8428],
#        [1772.6582],
#        [1779.0826],
#        [1782.7632],
#        [1782.0067],
#        [1778.4496],
#        [1773.6145],
#        [1771.411 ],
#        [1770.032 ],
#        [1771.2107],
#        [1774.245 ],
#        [1779.6144],
#        [1786.4564],
#        [1794.4097],
#        [1803.8406],
#        [1812.8491],
#        [1820.6613],
#        [1826.0226],
#        [1829.8265],
#        [1831.6459],
#        [1831.8856],
#        [1833.0558],
#        [1834.7897],
#        [1837.0391],
#        [1840.9004],
#        [1846.427 ],
#        [1855.3843],
#        [1866.3241],
#        [1878.9884],
#        [1892.5269],
#        [1903.6245],
#        [1908.2373],
#        [1910.7725],
#        [1908.867 ],
#        [1908.6453],
#        [1909.5144],
#        [1910.5419],
#        [1909.2009],
#        [1904.3265],
#        [1899.0913],
#        [1893.7198],
#        [1889.6353],
#        [1883.3429],
#        [1878.844 ],
#        [1877.2252],
#        [1879.0316],
#        [1883.5205],
#        [1890.5103],
#        [1897.1526],
#        [1902.0844],
#        [1903.5934],
#        [1900.9893],
#        [1893.25  ],
#        [1882.0455],
#        [1869.2733],
#        [1847.6775],
#        [1827.984 ],
#        [1809.4768],
#        [1792.3123],
#        [1781.0853],
#        [1772.7942],
#        [1764.7672],
#        [1757.595 ],
#        [1748.7693],
#        [1741.7483],
#        [1731.6312],
#        [1717.0338],
#        [1701.4409],
#        [1674.7136],
#        [1648.8937],
#        [1628.4219],
#        [1616.187 ],
#        [1608.5625],
#        [1602.0422],
#        [1600.5039],
#        [1607.4968],
#        [1617.8052],
#        [1627.4807],
#        [1633.0419],
#        [1636.2216],
#        [1632.6254],
#        [1625.6005],
#        [1616.0425],
#        [1596.244 ],
#        [1578.6694],
#        [1561.4393],
#        [1547.1567],
#        [1538.1073],
#        [1535.4672],
#        [1541.1198],
#        [1551.924 ],
#        [1571.31  ],
#        [1593.772 ],
#        [1607.5294],
#        [1621.1909],
#        [1628.1014],
#        [1634.0414],
#        [1638.0719],
#        [1641.3235],
#        [1641.0116],
#        [1633.8204],
#        [1621.1997],
#        [1606.1461],
#        [1586.535 ],
#        [1564.2213],
#        [1533.7367],
#        [1501.9326],
#        [1476.8677],
#        [1458.7899]], dtype=float32)

# %%
y_test
# Out:
# array([[1182.349976],
#        [1172.      ],
#        [1188.300049],
#        [1205.      ],
#        [1217.51001 ],
#        [1236.      ],
#        [1256.900024],
#        [1245.150024],
#        [1259.73999 ],
#        [1273.390015],
#        [1323.      ],
#        [1312.23999 ],
#        [1293.949951],
#        [1312.      ],
#        [1297.170044],
#        [1338.089966],
#        [1374.819946],
#        [1368.      ],
#        [1392.01001 ],
#        [1409.180054],
#        [1403.170044],
#        [1451.300049],
#        [1445.      ],
#        [1477.390015],
#        [1402.619995],
#        [1361.459961],
#        [1449.      ],
#        [1429.680054],
#        [1373.48999 ],
#        [1364.670044],
#        [1385.930054],
#        [1406.25    ],
#        [1466.890015],
#        [1457.369995],
#        [1446.48999 ],
#        [1485.      ],
#        [1495.359985],
#        [1495.339966],
#        [1509.199951],
#        [1524.5     ],
#        [1519.51001 ],
#        [1513.599976],
#        [1469.099976],
#        [1494.23999 ],
#        [1533.199951],
#        [1526.52002 ],
#        [1550.      ],
#        [1563.5     ],
#        [1592.599976],
#        [1615.959961],
#        [1597.      ],
#        [1595.      ],
#        [1583.449951],
#        [1554.530029],
#        [1550.339966],
#        [1586.449951],
#        [1565.469971],
#        [1539.01001 ],
#        [1530.      ],
#        [1572.400024],
#        [1447.      ],
#        [1406.      ],
#        [1417.619995],
#        [1391.380005],
#        [1358.23999 ],
#        [1441.98999 ],
#        [1429.969971],
#        [1425.030029],
#        [1431.98999 ],
#        [1439.439941],
#        [1439.5     ],
#        [1449.140015],
#        [1445.      ],
#        [1462.300049],
#        [1514.650024],
#        [1543.219971],
#        [1561.199951],
#        [1546.689941],
#        [1535.800049],
#        [1458.      ],
#        [1485.01001 ],
#        [1634.01001 ],
#        [1582.5     ],
#        [1563.219971],
#        [1580.97998 ],
#        [1560.01001 ],
#        [1562.449951],
#        [1589.339966],
#        [1595.      ],
#        [1600.      ],
#        [1608.47998 ],
#        [1610.98999 ],
#        [1604.      ],
#        [1587.800049],
#        [1577.5     ],
#        [1580.560059],
#        [1581.329956],
#        [1585.      ],
#        [1589.890015],
#        [1571.050049],
#        [1598.030029],
#        [1603.      ],
#        [1600.709961],
#        [1618.099976],
#        [1623.      ],
#        [1637.030029],
#        [1648.900024],
#        [1672.98999 ],
#        [1704.51001 ],
#        [1698.560059],
#        [1681.119995],
#        [1681.51001 ],
#        [1693.      ],
#        [1702.810059],
#        [1713.47998 ],
#        [1714.      ],
#        [1706.26001 ],
#        [1709.040039],
#        [1742.5     ],
#        [1760.      ],
#        [1742.619995],
#        [1702.51001 ],
#        [1672.369995],
#        [1708.109985],
#        [1672.540039],
#        [1717.      ],
#        [1682.699951],
#        [1723.959961],
#        [1705.380005],
#        [1696.      ],
#        [1724.050049],
#        [1738.530029],
#        [1737.98999 ],
#        [1764.51001 ],
#        [1803.930054],
#        [1821.949951],
#        [1811.560059],
#        [1848.      ],
#        [1829.459961],
#        [1825.01001 ],
#        [1812.209961],
#        [1829.01001 ],
#        [1829.300049],
#        [1839.      ],
#        [1876.050049],
#        [1827.329956],
#        [1786.48999 ],
#        [1784.      ],
#        [1788.77002 ],
#        [1837.73999 ],
#        [1825.810059],
#        [1854.530029],
#        [1861.      ],
#        [1882.      ],
#        [1888.51001 ],
#        [1898.5     ],
#        [1919.390015],
#        [1909.550049],
#        [1903.939941],
#        [1885.800049],
#        [1890.569946],
#        [1880.      ],
#        [1876.640015],
#        [1907.170044],
#        [1910.51001 ],
#        [1915.      ],
#        [1937.72998 ],
#        [1953.449951],
#        [1997.420044],
#        [2007.      ],
#        [2026.5     ],
#        [2038.109985],
#        [2006.51001 ],
#        [1938.709961],
#        [1971.      ],
#        [1928.27002 ],
#        [1994.      ],
#        [2000.      ],
#        [1992.930054],
#        [1954.72998 ],
#        [1918.650024],
#        [1940.5     ],
#        [1938.579956],
#        [1954.219971],
#        [1903.790039],
#        [1942.900024],
#        [1968.5     ],
#        [1993.23999 ],
#        [2004.410034],
#        [2021.98999 ],
#        [1999.98999 ],
#        [1981.699951],
#        [1949.      ],
#        [1917.98999 ],
#        [1874.      ],
#        [1859.98999 ],
#        [1857.890015],
#        [1724.      ],
#        [1808.      ],
#        [1795.      ],
#        [1783.5     ],
#        [1842.790039],
#        [1821.48999 ],
#        [1785.160034],
#        [1784.      ],
#        [1742.23999 ],
#        [1773.699951],
#        [1703.339966],
#        [1649.589966],
#        [1660.      ],
#        [1486.160034],
#        [1569.98999 ],
#        [1623.530029],
#        [1678.589966],
#        [1657.569946],
#        [1618.349976],
#        [1673.      ],
#        [1755.      ],
#        [1732.5     ],
#        [1698.23999 ],
#        [1649.290039],
#        [1656.319946],
#        [1581.01001 ],
#        [1587.5     ],
#        [1577.01001 ],
#        [1437.5     ],
#        [1542.98999 ],
#        [1517.      ],
#        [1539.      ],
#        [1575.98999 ],
#        [1613.920044],
#        [1674.98999 ],
#        [1679.5     ],
#        [1769.459961],
#        [1756.      ],
#        [1614.869995],
#        [1705.069946],
#        [1623.839966],
#        [1678.      ],
#        [1669.      ],
#        [1680.      ],
#        [1638.      ],
#        [1566.      ],
#        [1540.      ],
#        [1543.050049],
#        [1484.      ],
#        [1464.98999 ],
#        [1346.      ],
#        [1368.890015],
#        [1454.199951],
#        [1473.349976],
#        [1510.800049]])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mse = mean_squared_error(y_test, y_pred)

# %%
mse
# Out:
# 5865.7342367577885

# %%
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# np.float64(76.5880815581497)

# %% [markdown]
# On averge there is deviation of 63$ between the actual stock price and predicted stock price
#
# 1. we can expect a error of around 63 $ in prediction

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 63.43692936436628

# %%
test_data_dates = dataset.iloc[round(len(dataset) * 0.8): ].index

# %%
plt.figure(figsize = (15,5))
plt.plot(test_data_dates, y_test, label = "Actual stock data")
plt.plot(test_data_dates, y_pred, label = "Predicted stock data")
plt.legend()
plt.show()

# %% [markdown]
# ### Save the model

# %%
lstm_model.save("amazon_stock_model_lstm.keras")

# %% [markdown]
# ### Save the scaler object

# %%
import joblib

# %%
joblib.dump(sc, "amazon_stock_sc.pkl")
# Out:
# ['amazon_stock_sc.pkl']
